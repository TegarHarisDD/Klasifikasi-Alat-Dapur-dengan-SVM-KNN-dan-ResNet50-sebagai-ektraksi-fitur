# %% [markdown]
# ## Augmentasi part 3 dengan tambahan image greyscale
#
# - iaa.Grayscale(alpha=1.0)  # Konversi penuh ke greyscale

# %%
import os
import random
from PIL import Image, ImageEnhance
import imgaug.augmenters as iaa
import numpy as np

# %%
# Path ke dataset
dataset_path = 'dataset_preprocessed'

# %%
# Pipeline Augmentasi menggunakan imgaug
augmentation_pipeline = iaa.Sequential([
    iaa.Grayscale(alpha=1.0),  # Konversi penuh ke greyscale
    iaa.Multiply((0.5, 1.0)),  # Ubah kecerahan secara acak
    iaa.LinearContrast((0.5, 1.5)),  # Ubah kontras secara acak
    iaa.GaussianBlur(sigma=(0.0, 1.0)),  # Tambah blur Gaussian
    iaa.Affine(rotate=(-25, 25)),  # Putar gambar secara acak
    iaa.Affine(scale=(0.8, 1.2)),  # Skala gambar secara acak
    iaa.AdditiveGaussianNoise(scale=(0, 0.05*255)),  # Tambah noise
    iaa.Crop(percent=(0, 0.1)),  # Potong gambar secara acak
    iaa.PiecewiseAffine(scale=(0.01, 0.05)),  # Transformasi affine secara acak
])

# %%
def augment_image(image_path, save_dir, augment_count=5):
    # Buka gambar
    image = Image.open(image_path)
    image = np.array(image)  # Ubah gambar ke array numpy untuk proses imgaug

    # Buat gambar augmented
    for i in range(augment_count):
        # Augmentasi gambar
        augmented_image = augmentation_pipeline(image=image)
        augmented_image = Image.fromarray(augmented_image)  # Kembali ke gambar PIL
        
        # Simpan gambar augmented
        filename = f"{os.path.splitext(os.path.basename(image_path))[0]}_aug3_{i}.png"
        augmented_image.save(os.path.join(save_dir, filename))

def process_dataset(dataset_path):
    # Telusuri folder dataset
    for class_name in os.listdir(dataset_path):
        class_folder = os.path.join(dataset_path, class_name)
        
        if os.path.isdir(class_folder):
            save_dir = os.path.join(class_folder, "augmented")
            os.makedirs(save_dir, exist_ok=True)  # Buat folder untuk menyimpan gambar augmented
            
            # Loop melalui semua gambar di folder kelas
            for image_name in os.listdir(class_folder):
                image_path = os.path.join(class_folder, image_name)
                
                if image_path.lower().endswith(('.png', '.jpg', '.jpeg')):  # Hanya proses file gambar
                    augment_image(image_path, save_dir)
                    print(f"Gambar augmented untuk {image_name} disimpan di {save_dir}")

# %%
# Mulai proses augmentasi
process_dataset(dataset_path)
# Out:
# Gambar augmented untuk 1000101132.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101133.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101135.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101136 - Copy.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101136.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101137 - Copy.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101137.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101138 - Copy.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101138.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101139 - Copy.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101139.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101140 - Copy.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101140.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101141.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101142.jpg disimpan di dataset_preprocessed\alat_kupas\augmented
# Gambar augmented untuk 1000101148.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101149.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101150.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101151.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101152.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101153.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101154.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101155.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101157.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101158.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101159.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101160.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101161.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101162.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101163.jpg disimpan di dataset_preprocessed\centong_nasi\augmented
# Gambar augmented untuk 1000101164.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101165.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101166.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101167.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101168.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101169.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101170.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101171.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101172.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101173.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101174.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101175.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101176.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101177.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101178.jpg disimpan di dataset_preprocessed\garpu\augmented
# Gambar augmented untuk 1000101102.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101103.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101104.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101105.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101106.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101107.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101108.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101109.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101110.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101111.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101112.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101113.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101114.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101115.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101116.jpg disimpan di dataset_preprocessed\gunting\augmented
# Gambar augmented untuk 1000101117.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101118.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101119.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101120.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101121.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101122.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101123.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101124.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101125.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101126.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101127.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101128.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101129.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101130.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101131.jpg disimpan di dataset_preprocessed\pisau\augmented
# Gambar augmented untuk 1000101179.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101180.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101181.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101182.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101183.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101184.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101185.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101186.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101187.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101188.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101189.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101190.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101191.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101192.jpg disimpan di dataset_preprocessed\sendok\augmented
# Gambar augmented untuk 1000101193.jpg disimpan di dataset_preprocessed\sendok\augmented
